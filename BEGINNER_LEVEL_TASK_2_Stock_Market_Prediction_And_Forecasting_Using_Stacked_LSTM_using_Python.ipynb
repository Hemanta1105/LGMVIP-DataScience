# %% [markdown]
# # **NAME : HEMANTA SETHI**
# # **DATA SCIENCE INTERN AT LETSGROWMORE LGMVIPJANUARY**
# ## BEGINNER LEVEL TASK 1 :

# %% [markdown]
# ## **Stock Market Prediction And Forecasting Using Stacked LSTM**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing  import MinMaxScaler

# %%
data=pd.read_csv("https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv")

# %%
data.head()
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-09-28  234.05  235.95  ...  233.75               3069914          7162.35
# 1  2018-09-27  234.55  236.80  ...  233.25               5082859         11859.95
# 2  2018-09-26  240.00  240.00  ...  234.25               2240909          5248.60
# 3  2018-09-25  233.30  236.75  ...  236.10               2349368          5503.90
# 4  2018-09-24  233.55  239.20  ...  233.30               3423509          7999.55
#
# [5 rows x 8 columns]

# %%
data.tail()
# Out:
#             Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2030  2010-07-27  117.6  119.50  ...  118.65                586100           694.98
# 2031  2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2032  2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2033  2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2034  2010-07-21  122.1  123.00  ...  121.55                658666           803.56
#
# [5 rows x 8 columns]

# %%
data['Date']=pd.to_datetime(data['Date'])
print(type(data.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=data.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 2034 2010-07-21  122.1  123.00  ...  121.55                658666           803.56
# 2033 2010-07-22  120.3  122.00  ...  120.90                293312           355.17
# 2032 2010-07-23  121.8  121.95  ...  120.65                281312           340.31
# 2031 2010-07-26  120.1  121.00  ...  117.60                658440           780.01
# 2030 2010-07-27  117.6  119.50  ...  118.65                586100           694.98
#
# [5 rows x 8 columns]

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index       Date   Open  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0   2034 2010-07-21  122.1  ...  121.55                658666           803.56
# 1   2033 2010-07-22  120.3  ...  120.90                293312           355.17
# 2   2032 2010-07-23  121.8  ...  120.65                281312           340.31
# 3   2031 2010-07-26  120.1  ...  117.60                658440           780.01
# 4   2030 2010-07-27  117.6  ...  118.65                586100           694.98
#
# [5 rows x 9 columns]

# %%
plt.plot(df['Close'])

# %%
df1=df['Close']

# %% [markdown]
# ## **PREPARING DATA**

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
df1
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %%
training_size=int(len(df1)*0.70)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (1424, 611)

# %%
def create_dataset(dataset, timestep=1):
    dataX, dataY=[], []
    for i in range(len(dataset)-time_step-1): 
            a = dataset[i:(i+time_step), 0]
            dataX.append(a)
            dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(y_test.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# # **MODEL BUILDING**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')   
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=60,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 10s 249ms/step - loss: 0.0118 - val_loss: 0.0013
# Epoch 2/60
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 3/60
# 19/19 [==============================] - 3s 179ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 3s 178ms/step - loss: 9.0852e-04 - val_loss: 0.0011
# Epoch 5/60
# 19/19 [==============================] - 3s 179ms/step - loss: 8.4633e-04 - val_loss: 0.0012
# Epoch 6/60
# 19/19 [==============================] - 3s 178ms/step - loss: 8.2911e-04 - val_loss: 0.0011
# Epoch 7/60
# 19/19 [==============================] - 3s 180ms/step - loss: 7.8329e-04 - val_loss: 0.0010
# Epoch 8/60
# 19/19 [==============================] - 3s 179ms/step - loss: 7.5957e-04 - val_loss: 9.7012e-04
# Epoch 9/60
# 19/19 [==============================] - 3s 178ms/step - loss: 7.5747e-04 - val_loss: 9.4362e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 181ms/step - loss: 7.1278e-04 - val_loss: 9.2297e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 180ms/step - loss: 7.0736e-04 - val_loss: 8.3060e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 180ms/step - loss: 7.0151e-04 - val_loss: 8.4258e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 180ms/step - loss: 6.6740e-04 - val_loss: 8.3033e-04
# Epoch 14/60
# 19/19 [==============================] - 3s 180ms/step - loss: 6.3245e-04 - val_loss: 7.1716e-04
# Epoch 15/60
# 19/19 [==============================] - 3s 178ms/step - loss: 5.8780e-04 - val_loss: 7.2047e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 179ms/step - loss: 5.8242e-04 - val_loss: 6.3189e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 179ms/step - loss: 5.6303e-04 - val_loss: 6.4464e-04
# Epoch 18/60
# 19/19 [==============================] - 3s 180ms/step - loss: 5.4743e-04 - val_loss: 5.7221e-04
# Epoch 19/60
# 19/19 [==============================] - 3s 180ms/step - loss: 5.3242e-04 - val_loss: 6.2249e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 179ms/step - loss: 5.1145e-04 - val_loss: 5.5186e-04
# Epoch 21/60
# 19/19 [==============================] - 3s 178ms/step - loss: 4.9998e-04 - val_loss: 5.5200e-04
# Epoch 22/60
# 19/19 [==============================] - 3s 179ms/step - loss: 4.8021e-04 - val_loss: 4.9402e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 179ms/step - loss: 4.6044e-04 - val_loss: 4.7040e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 178ms/step - loss: 4.5374e-04 - val_loss: 4.8411e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 179ms/step - loss: 4.3829e-04 - val_loss: 4.4083e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 182ms/step - loss: 4.1992e-04 - val_loss: 4.1325e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 182ms/step - loss: 4.1994e-04 - val_loss: 5.2418e-04
# Epoch 28/60
# 19/19 [==============================] - 4s 186ms/step - loss: 4.0921e-04 - val_loss: 3.9831e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 182ms/step - loss: 4.0532e-04 - val_loss: 4.6910e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 182ms/step - loss: 3.9762e-04 - val_loss: 3.5925e-04
# Epoch 31/60
# 19/19 [==============================] - 4s 185ms/step - loss: 4.0504e-04 - val_loss: 3.5528e-04
# Epoch 32/60
# 19/19 [==============================] - 3s 182ms/step - loss: 3.6607e-04 - val_loss: 4.0988e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 180ms/step - loss: 3.4700e-04 - val_loss: 3.2096e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 182ms/step - loss: 3.3752e-04 - val_loss: 3.1600e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 183ms/step - loss: 3.8574e-04 - val_loss: 4.0815e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 182ms/step - loss: 3.3509e-04 - val_loss: 3.0340e-04
# Epoch 37/60
# 19/19 [==============================] - 4s 185ms/step - loss: 3.1069e-04 - val_loss: 2.8792e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 181ms/step - loss: 3.1875e-04 - val_loss: 2.8041e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 181ms/step - loss: 3.0331e-04 - val_loss: 2.7129e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 184ms/step - loss: 3.0217e-04 - val_loss: 2.6544e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 183ms/step - loss: 2.8762e-04 - val_loss: 3.4256e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 182ms/step - loss: 3.0552e-04 - val_loss: 3.0315e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 183ms/step - loss: 2.8114e-04 - val_loss: 2.3545e-04
# Epoch 44/60
# 19/19 [==============================] - 3s 182ms/step - loss: 2.5950e-04 - val_loss: 2.2495e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 182ms/step - loss: 2.5554e-04 - val_loss: 2.2516e-04
# Epoch 46/60
# 19/19 [==============================] - 4s 187ms/step - loss: 2.5471e-04 - val_loss: 2.1375e-04
# Epoch 47/60
# 19/19 [==============================] - 4s 186ms/step - loss: 2.5531e-04 - val_loss: 2.2212e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 184ms/step - loss: 2.6203e-04 - val_loss: 2.3224e-04
# Epoch 49/60
# 19/19 [==============================] - 4s 186ms/step - loss: 2.4192e-04 - val_loss: 2.0435e-04
# Epoch 50/60
# 19/19 [==============================] - 4s 183ms/step - loss: 2.3798e-04 - val_loss: 1.9516e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 182ms/step - loss: 2.2904e-04 - val_loss: 2.0155e-04
# Epoch 52/60
# 19/19 [==============================] - 3s 183ms/step - loss: 2.4538e-04 - val_loss: 2.0991e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 181ms/step - loss: 2.3826e-04 - val_loss: 1.8768e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 183ms/step - loss: 2.1667e-04 - val_loss: 1.7717e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 182ms/step - loss: 2.1683e-04 - val_loss: 1.8715e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 181ms/step - loss: 2.1585e-04 - val_loss: 2.1693e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 180ms/step - loss: 2.1765e-04 - val_loss: 1.7686e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 181ms/step - loss: 1.9943e-04 - val_loss: 1.6977e-04
# Epoch 59/60
# 19/19 [==============================] - 3s 183ms/step - loss: 2.0818e-04 - val_loss: 1.8448e-04
# Epoch 60/60
# 19/19 [==============================] - 3s 182ms/step - loss: 1.8716e-04 - val_loss: 1.8503e-04

# %%
test_predict=model.predict(X_test)

# %%
test_predict1=scaler.inverse_transform(test_predict)

# %%
test_predict1
# Out:
# array([[140.24109 ],
#        [140.42534 ],
#        [139.469   ],
#        [136.68121 ],
#        [135.02269 ],
#        [134.52298 ],
#        [135.80777 ],
#        [137.46242 ],
#        [137.86334 ],
#        [137.49973 ],
#        [137.28206 ],
#        [138.54091 ],
#        [139.31357 ],
#        [140.89124 ],
#        [143.08601 ],
#        [140.8562  ],
#        [138.31775 ],
#        [137.95854 ],
#        [138.58838 ],
#        [143.774   ],
#        [148.19678 ],
#        [150.30817 ],
#        [150.60493 ],
#        [148.43422 ],
#        [148.19228 ],
#        [147.85098 ],
#        [148.17566 ],
#        [149.84799 ],
#        [150.55084 ],
#        [150.56197 ],
#        [150.99452 ],
#        [149.81987 ],
#        [146.53204 ],
#        [140.74069 ],
#        [137.37009 ],
#        [136.47742 ],
#        [136.72812 ],
#        [135.96613 ],
#        [133.67513 ],
#        [129.97806 ],
#        [127.55302 ],
#        [126.48611 ],
#        [124.37707 ],
#        [123.63636 ],
#        [121.556786],
#        [118.87085 ],
#        [118.28071 ],
#        [118.07127 ],
#        [118.40671 ],
#        [117.430595],
#        [116.52652 ],
#        [116.12791 ],
#        [115.291565],
#        [115.45689 ],
#        [116.8816  ],
#        [118.75508 ],
#        [120.74975 ],
#        [121.49896 ],
#        [121.17224 ],
#        [121.114075],
#        [121.21852 ],
#        [121.003975],
#        [121.186035],
#        [121.60177 ],
#        [121.8381  ],
#        [121.921776],
#        [121.75823 ],
#        [122.103   ],
#        [122.606964],
#        [123.00609 ],
#        [122.23898 ],
#        [121.23507 ],
#        [119.8459  ],
#        [118.56493 ],
#        [117.23187 ],
#        [117.40433 ],
#        [118.06391 ],
#        [119.12353 ],
#        [120.304596],
#        [121.60888 ],
#        [122.80168 ],
#        [123.48826 ],
#        [123.87139 ],
#        [123.78287 ],
#        [123.49069 ],
#        [123.111145],
#        [123.83119 ],
#        [124.14368 ],
#        [125.10876 ],
#        [125.932915],
#        [126.35084 ],
#        [126.78552 ],
#        [127.740616],
#        [127.26791 ],
#        [126.672585],
#        [126.52752 ],
#        [126.65239 ],
#        [127.14104 ],
#        [128.0716  ],
#        [128.35208 ],
#        [128.58972 ],
#        [131.36478 ],
#        [135.9773  ],
#        [140.00755 ],
#        [141.64035 ],
#        [143.0421  ],
#        [143.01944 ],
#        [142.23196 ],
#        [140.67728 ],
#        [139.14664 ],
#        [137.42859 ],
#        [136.91774 ],
#        [137.35071 ],
#        [138.66563 ],
#        [139.93646 ],
#        [140.07741 ],
#        [139.34079 ],
#        [138.38278 ],
#        [137.38431 ],
#        [138.82835 ],
#        [139.91698 ],
#        [141.07445 ],
#        [141.76428 ],
#        [141.70415 ],
#        [140.76096 ],
#        [139.54396 ],
#        [137.30122 ],
#        [136.40422 ],
#        [137.13293 ],
#        [139.76747 ],
#        [142.27823 ],
#        [144.26636 ],
#        [144.9714  ],
#        [143.64183 ],
#        [145.21877 ],
#        [147.4257  ],
#        [147.78033 ],
#        [147.84334 ],
#        [147.86714 ],
#        [147.69266 ],
#        [147.68414 ],
#        [148.35548 ],
#        [149.40126 ],
#        [150.3474  ],
#        [149.85283 ],
#        [149.08203 ],
#        [149.6115  ],
#        [149.8437  ],
#        [149.26776 ],
#        [148.1784  ],
#        [146.84941 ],
#        [146.86244 ],
#        [148.30609 ],
#        [149.37952 ],
#        [150.019   ],
#        [150.08128 ],
#        [150.67325 ],
#        [150.53807 ],
#        [150.46596 ],
#        [152.36899 ],
#        [153.67894 ],
#        [153.66376 ],
#        [151.79813 ],
#        [150.11446 ],
#        [149.95837 ],
#        [150.90816 ],
#        [151.56403 ],
#        [151.24323 ],
#        [151.50006 ],
#        [151.89568 ],
#        [151.46832 ],
#        [148.6119  ],
#        [146.81255 ],
#        [145.69191 ],
#        [144.07742 ],
#        [141.72174 ],
#        [140.66685 ],
#        [142.26227 ],
#        [143.75943 ],
#        [144.50201 ],
#        [146.09981 ],
#        [148.59676 ],
#        [151.29507 ],
#        [152.80324 ],
#        [152.16199 ],
#        [151.81523 ],
#        [151.39258 ],
#        [150.99255 ],
#        [149.86586 ],
#        [150.80087 ],
#        [153.2297  ],
#        [155.5284  ],
#        [156.3698  ],
#        [155.4559  ],
#        [154.42789 ],
#        [153.85576 ],
#        [152.87445 ],
#        [150.64262 ],
#        [147.34737 ],
#        [145.93538 ],
#        [145.82188 ],
#        [147.20146 ],
#        [149.04417 ],
#        [149.59468 ],
#        [151.7791  ],
#        [152.56076 ],
#        [153.98117 ],
#        [158.71536 ],
#        [163.93706 ],
#        [168.53464 ],
#        [171.26726 ],
#        [171.2059  ],
#        [171.1398  ],
#        [169.66914 ],
#        [168.98369 ],
#        [167.39973 ],
#        [166.82196 ],
#        [166.21896 ],
#        [166.63286 ],
#        [167.94133 ],
#        [167.33725 ],
#        [166.64407 ],
#        [166.51314 ],
#        [165.69826 ],
#        [163.8468  ],
#        [163.16418 ],
#        [163.18207 ],
#        [165.19841 ],
#        [164.97464 ],
#        [162.05725 ],
#        [156.74957 ],
#        [156.74757 ],
#        [165.47427 ],
#        [180.26521 ],
#        [188.55307 ],
#        [191.25493 ],
#        [190.92186 ],
#        [186.30417 ],
#        [185.41852 ],
#        [185.37503 ],
#        [185.32047 ],
#        [184.22203 ],
#        [186.94832 ],
#        [190.3797  ],
#        [192.16516 ],
#        [190.43146 ],
#        [190.11618 ],
#        [194.96999 ],
#        [198.73871 ],
#        [200.4366  ],
#        [201.52208 ],
#        [203.0116  ],
#        [201.33661 ],
#        [201.83008 ],
#        [202.04199 ],
#        [203.42888 ],
#        [205.91776 ],
#        [206.16133 ],
#        [204.87453 ],
#        [198.41455 ],
#        [191.91049 ],
#        [193.35915 ],
#        [193.5897  ],
#        [195.68256 ],
#        [198.5834  ],
#        [200.30228 ],
#        [199.72888 ],
#        [200.73663 ],
#        [201.51514 ],
#        [200.92584 ],
#        [200.20853 ],
#        [200.29416 ],
#        [201.87123 ],
#        [202.18503 ],
#        [201.65968 ],
#        [201.59956 ],
#        [200.04367 ],
#        [197.89502 ],
#        [196.15646 ],
#        [198.9035  ],
#        [199.38045 ],
#        [201.1079  ],
#        [207.47272 ],
#        [214.49016 ],
#        [217.47275 ],
#        [217.66794 ],
#        [216.00388 ],
#        [214.14188 ],
#        [217.97972 ],
#        [216.55678 ],
#        [214.48752 ],
#        [221.60587 ],
#        [225.0265  ],
#        [224.65892 ],
#        [229.54126 ],
#        [234.79207 ],
#        [237.4057  ],
#        [241.50513 ],
#        [250.39194 ],
#        [254.11792 ],
#        [254.9041  ],
#        [254.9956  ],
#        [256.90894 ],
#        [257.7571  ],
#        [263.07425 ],
#        [262.78336 ],
#        [265.23996 ],
#        [265.21222 ],
#        [262.95663 ],
#        [262.37167 ],
#        [260.2734  ],
#        [263.76346 ],
#        [268.144   ],
#        [274.50964 ],
#        [272.33215 ],
#        [268.54306 ],
#        [266.68936 ],
#        [267.605   ],
#        [270.41    ],
#        [276.35275 ],
#        [279.16296 ],
#        [279.46655 ],
#        [280.34882 ],
#        [282.24557 ],
#        [283.0769  ],
#        [283.91705 ],
#        [288.77744 ],
#        [289.77533 ],
#        [289.13824 ],
#        [288.84924 ],
#        [289.45932 ],
#        [290.3391  ],
#        [292.9664  ],
#        [293.2802  ],
#        [292.7315  ],
#        [292.12976 ],
#        [297.48782 ],
#        [299.02625 ],
#        [296.44025 ],
#        [293.7363  ],
#        [289.11798 ],
#        [288.67703 ],
#        [289.3053  ],
#        [289.01407 ],
#        [287.41296 ],
#        [286.5448  ],
#        [285.04727 ],
#        [285.30106 ],
#        [279.32092 ],
#        [275.15985 ],
#        [267.25046 ],
#        [262.9946  ],
#        [258.70212 ],
#        [263.53485 ],
#        [266.4064  ],
#        [265.76993 ],
#        [267.64566 ],
#        [266.75974 ],
#        [264.331   ],
#        [261.3023  ],
#        [256.32684 ],
#        [251.7067  ],
#        [251.94441 ],
#        [250.74362 ],
#        [254.20053 ],
#        [257.43652 ],
#        [259.11978 ],
#        [259.44116 ],
#        [258.7739  ],
#        [258.5737  ],
#        [257.82318 ],
#        [255.00388 ],
#        [255.83464 ],
#        [254.4628  ],
#        [257.38306 ],
#        [260.2385  ],
#        [261.46927 ],
#        [262.11102 ],
#        [258.8036  ],
#        [251.20992 ],
#        [248.39636 ],
#        [248.87892 ],
#        [247.70488 ],
#        [246.57376 ],
#        [248.16646 ],
#        [249.8661  ],
#        [247.89095 ],
#        [254.90083 ],
#        [257.88385 ],
#        [256.01498 ],
#        [255.51324 ],
#        [255.34245 ],
#        [257.83057 ],
#        [258.29456 ],
#        [257.51068 ],
#        [257.12155 ],
#        [257.96533 ],
#        [260.59045 ],
#        [262.59332 ],
#        [264.7708  ],
#        [266.59784 ],
#        [267.29428 ],
#        [266.16266 ],
#        [265.3112  ],
#        [267.92358 ],
#        [270.55823 ],
#        [272.11462 ],
#        [275.09158 ],
#        [274.29    ],
#        [270.7142  ],
#        [269.5803  ],
#        [272.63815 ],
#        [272.49664 ],
#        [273.18216 ],
#        [270.42026 ],
#        [269.98642 ],
#        [254.98431 ],
#        [240.5308  ],
#        [234.63794 ],
#        [237.46513 ],
#        [238.64394 ],
#        [237.92554 ],
#        [238.48575 ],
#        [239.72385 ],
#        [241.71425 ],
#        [243.60194 ],
#        [245.12595 ],
#        [243.76619 ],
#        [245.7868  ],
#        [249.36456 ],
#        [248.31216 ],
#        [243.28764 ],
#        [244.86288 ],
#        [247.9197  ],
#        [250.298   ],
#        [251.16722 ],
#        [249.73703 ],
#        [250.67358 ],
#        [252.47203 ],
#        [257.25815 ],
#        [257.00546 ],
#        [257.53482 ],
#        [253.92348 ],
#        [248.91714 ],
#        [245.61615 ],
#        [246.81633 ],
#        [249.43507 ],
#        [252.12132 ],
#        [252.22203 ],
#        [250.8201  ],
#        [252.40327 ],
#        [251.07233 ],
#        [257.81314 ],
#        [259.97928 ],
#        [257.16812 ],
#        [252.7762  ],
#        [255.15118 ],
#        [257.13574 ],
#        [255.68523 ],
#        [252.42853 ],
#        [247.88814 ],
#        [238.28566 ],
#        [236.27449 ],
#        [232.40771 ],
#        [227.91116 ],
#        [228.83203 ],
#        [232.4321  ],
#        [235.50732 ],
#        [231.50795 ],
#        [229.02051 ],
#        [229.51254 ],
#        [230.06279 ],
#        [232.42143 ],
#        [228.10706 ],
#        [224.74084 ],
#        [223.23148 ],
#        [225.56006 ],
#        [226.51004 ],
#        [225.99818 ],
#        [225.90825 ],
#        [224.06375 ],
#        [223.3843  ],
#        [224.86174 ],
#        [226.83046 ],
#        [229.4795  ],
#        [231.6588  ],
#        [230.07213 ],
#        [225.96883 ],
#        [221.53453 ],
#        [222.85356 ],
#        [223.06323 ],
#        [223.64197 ],
#        [224.75388 ],
#        [224.46452 ],
#        [225.13228 ],
#        [219.06625 ],
#        [214.29861 ],
#        [212.07074 ],
#        [212.86107 ],
#        [213.54454 ],
#        [210.78575 ],
#        [212.05717 ],
#        [219.07869 ],
#        [224.47333 ],
#        [225.19897 ],
#        [223.9081  ],
#        [222.47952 ],
#        [221.13498 ],
#        [222.06854 ],
#        [222.27863 ]], dtype=float32)

# %%
## calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_test,test_predict))
# Out:
# 0.04907746184527671
